# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishanta04/Algorithms/blob/main/Kadane's_Algorithm(Max_Subarray).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l = [-2,1,2,2,-8,2,1]
cur_sum = l[0]
max_sum = l[0]
for i,j in enumerate(l):
  print(i,j)
# Out:
# 0 -2
# 1 1
# 2 2
# 3 2
# 4 -8
# 5 2
# 6 1
